# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Dirty-Data" data-toc-modified-id="Dirty-Data-1">Dirty Data</a></span></li><li><span><a href="#Messy-Data" data-toc-modified-id="Messy-Data-2">Messy Data</a></span><ul class="toc-item"><li><span><a href="#fill-missing-values" data-toc-modified-id="fill-missing-values-2.1">fill missing values</a></span></li><li><span><a href="#Fixing-data-type-of-columns" data-toc-modified-id="Fixing-data-type-of-columns-2.2">Fixing data type of columns</a></span></li><li><span><a href="#Data-cleaning-batsman-name" data-toc-modified-id="Data-cleaning-batsman-name-2.3">Data cleaning batsman name</a></span></li><li><span><a href="#Data-cleaning-wicket_taken-column" data-toc-modified-id="Data-cleaning-wicket_taken-column-2.4">Data cleaning wicket_taken column</a></span></li><li><span><a href="#Fixing-structure-of-data" data-toc-modified-id="Fixing-structure-of-data-2.5">Fixing structure of data</a></span><ul class="toc-item"><li><span><a href="#derived-column-from-wicket_taken" data-toc-modified-id="derived-column-from-wicket_taken-2.5.1">derived column from wicket_taken</a></span></li></ul></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Batters_uncleaned_data.csv')

# %%
df
# Out:
#       Unnamed: 0           batsman total_runs total_balls fours sixes  \
# 0              0       Tamim Iqbal         62          46     4     4
# 1              1   Mohammad Hafeez         16          19     2     0
# 2              2      Kamran Akmal          0           3     0     0
# 3              3       Eoin Morgan          1           4     0     0
# 4              4    Sohaib Maqsood         30          24     2     1
# ...          ...               ...        ...         ...   ...   ...
# 4491           1  Laurie Evans ï¿½          7           4     1     0
# 4492           2  Laurie Evans ï¿½          1           2     0     0
# 4493           3  Laurie Evans ï¿½          0           1     0     0
# 4494           0     Arafat Minhas          1           1     0     0
# 4495           0        Obed McCoy          0           1     0     0
#
#      strike_rate                          wicket_taken  season  \
# 0         134.78                               not out  2017.0
# 1          84.21           c Hassan Khan b Mahmudullah  2017.0
# 2            0.0           c Asad Shafiq b Hassan Khan  2017.0
# 3           25.0               c Asad Shafiq b Rossouw  2017.0
# 4          125.0                               not out  2017.0
# ...          ...                                   ...     ...
# 4491      175.00    c Mirza Baig b Shaheen Shah Afridi  2024.0
# 4492       50.00               c Jordan b Abbas Afridi  2024.0
# 4493        0.00  run out (Faheem Ashraf/ï¿½Azam Khan)  2024.0
# 4494      100.00       run out (Sikandar Raza/ï¿½Hope)  2024.0
# 4495        0.00                               not out  2024.0
#
#                         stadium               team      opposing_team
# 0       Sharjah Cricket Stadium     Peshawar Zalmi  Quetta Gladiators
# 1       Sharjah Cricket Stadium     Peshawar Zalmi  Quetta Gladiators
# 2       Sharjah Cricket Stadium     Peshawar Zalmi  Quetta Gladiators
# 3       Sharjah Cricket Stadium     Peshawar Zalmi  Quetta Gladiators
# 4       Sharjah Cricket Stadium     Peshawar Zalmi  Quetta Gladiators
# ...                         ...                ...                ...
# 4491  National Stadium, Karachi  Quetta Gladiators   Lahore Qalandars
# 4492  National Stadium, Karachi  Quetta Gladiators     Multan Sultans
# 4493  National Stadium, Karachi  Quetta Gladiators   Islamabad United
# 4494  National Stadium, Karachi      Karachi Kings   Lahore Qalandars
# 4495  National Stadium, Karachi   Islamabad United  Quetta Gladiators
#
# [4496 rows x 12 columns]

# %% [markdown]
# # Data Cleaning
#
# ## Dirty Data
# **Issue with data quality**<br>
# - `Batsman name`: **ï¿½** invalid characters `invalid`
# - `Strike rate`: some rows contains **"-"** `invalid`
# - `total_runs`: 4092 index contains **"-"** `invalid`
# - `wicket_taken`: some rows contains **ï¿½** `invalid`
# - `season`: missing value `completness`
# - `Invalid types`:<br>
#     - season: 2022.0 float
#     - total_runs type object
#     - total_balls type object
#     - total_fours type object
#     - total_sixes type object
#     - strike_rate type object
#
#
#
# ## Messy Data
# **Issue with structure of data**<br>
# `Unnamed: 0`: extra column
# `wicket_taken`: wicket type and name of wicket taker together<br>
# `derived column`: seperate column for whether a player is captain or not.

# %%
df
# Out:
#       Unnamed: 0           batsman total_runs total_balls fours sixes  \
# 0              0       Tamim Iqbal         62          46     4     4
# 1              1   Mohammad Hafeez         16          19     2     0
# 2              2      Kamran Akmal          0           3     0     0
# 3              3       Eoin Morgan          1           4     0     0
# 4              4    Sohaib Maqsood         30          24     2     1
# ...          ...               ...        ...         ...   ...   ...
# 4491           1  Laurie Evans ï¿½          7           4     1     0
# 4492           2  Laurie Evans ï¿½          1           2     0     0
# 4493           3  Laurie Evans ï¿½          0           1     0     0
# 4494           0     Arafat Minhas          1           1     0     0
# 4495           0        Obed McCoy          0           1     0     0
#
#      strike_rate                          wicket_taken  season  \
# 0         134.78                               not out  2017.0
# 1          84.21           c Hassan Khan b Mahmudullah  2017.0
# 2            0.0           c Asad Shafiq b Hassan Khan  2017.0
# 3           25.0               c Asad Shafiq b Rossouw  2017.0
# 4          125.0                               not out  2017.0
# ...          ...                                   ...     ...
# 4491      175.00    c Mirza Baig b Shaheen Shah Afridi  2024.0
# 4492       50.00               c Jordan b Abbas Afridi  2024.0
# 4493        0.00  run out (Faheem Ashraf/ï¿½Azam Khan)  2024.0
# 4494      100.00       run out (Sikandar Raza/ï¿½Hope)  2024.0
# 4495        0.00                               not out  2024.0
#
#                         stadium               team      opposing_team
# 0       Sharjah Cricket Stadium     Peshawar Zalmi  Quetta Gladiators
# 1       Sharjah Cricket Stadium     Peshawar Zalmi  Quetta Gladiators
# 2       Sharjah Cricket Stadium     Peshawar Zalmi  Quetta Gladiators
# 3       Sharjah Cricket Stadium     Peshawar Zalmi  Quetta Gladiators
# 4       Sharjah Cricket Stadium     Peshawar Zalmi  Quetta Gladiators
# ...                         ...                ...                ...
# 4491  National Stadium, Karachi  Quetta Gladiators   Lahore Qalandars
# 4492  National Stadium, Karachi  Quetta Gladiators     Multan Sultans
# 4493  National Stadium, Karachi  Quetta Gladiators   Islamabad United
# 4494  National Stadium, Karachi      Karachi Kings   Lahore Qalandars
# 4495  National Stadium, Karachi   Islamabad United  Quetta Gladiators
#
# [4496 rows x 12 columns]

# %%
df.tail(10)
# Out:
#       Unnamed: 0           batsman total_runs total_balls fours sixes  \
# 4486           1       Usman Tariq          0           2     0     0
# 4487           2       Usman Tariq          1           1     0     0
# 4488           0         Shai Hope          6           9     0     0
# 4489           0     Mehran Mumtaz          0           1     0     0
# 4490           0  Laurie Evans ï¿½         12          13     2     0
# 4491           1  Laurie Evans ï¿½          7           4     1     0
# 4492           2  Laurie Evans ï¿½          1           2     0     0
# 4493           3  Laurie Evans ï¿½          0           1     0     0
# 4494           0     Arafat Minhas          1           1     0     0
# 4495           0        Obed McCoy          0           1     0     0
#
#      strike_rate                          wicket_taken  season  \
# 4486        0.00                               not out  2024.0
# 4487      100.00                               not out  2024.0
# 4488       66.66                    c Cox b Imad Wasim  2024.0
# 4489        0.00                              b Hosein  2024.0
# 4490       92.30                c Powell b Aamer Jamal  2024.0
# 4491      175.00    c Mirza Baig b Shaheen Shah Afridi  2024.0
# 4492       50.00               c Jordan b Abbas Afridi  2024.0
# 4493        0.00  run out (Faheem Ashraf/ï¿½Azam Khan)  2024.0
# 4494      100.00       run out (Sikandar Raza/ï¿½Hope)  2024.0
# 4495        0.00                               not out  2024.0
#
#                          stadium               team      opposing_team
# 4486   National Stadium, Karachi  Quetta Gladiators     Multan Sultans
# 4487   National Stadium, Karachi  Quetta Gladiators   Islamabad United
# 4488  Rawalpindi Cricket Stadium   Lahore Qalandars   Islamabad United
# 4489  Rawalpindi Cricket Stadium     Peshawar Zalmi  Quetta Gladiators
# 4490  Rawalpindi Cricket Stadium  Quetta Gladiators     Peshawar Zalmi
# 4491   National Stadium, Karachi  Quetta Gladiators   Lahore Qalandars
# 4492   National Stadium, Karachi  Quetta Gladiators     Multan Sultans
# 4493   National Stadium, Karachi  Quetta Gladiators   Islamabad United
# 4494   National Stadium, Karachi      Karachi Kings   Lahore Qalandars
# 4495   National Stadium, Karachi   Islamabad United  Quetta Gladiators

# %%
df.sample(10)
# Out:
#       Unnamed: 0            batsman total_runs total_balls fours sixes  \
# 846           17         Wahab Riaz         28          14     4     1
# 1045          48     Iftikhar Ahmed          4           6     0     0
# 3784          14     Mohammad Wasim          4           2     1     0
# 954           25         Imad Wasim          1           3     0     0
# 3650           5          Saim Ayub         35          31     5     0
# 812            3      Shahid Yousaf         16          11     3     0
# 1674           1        Eoin Morgan         80          57     8     3
# 4063          22  Abdullah Shafique         11          10     0     1
# 922           27        Ravi Bopara          9           5     0     1
# 2631          10        Salman Agha          3           6     0     0
#
#      strike_rate                      wicket_taken  season  \
# 846       200.00                           not out  2018.0
# 1045       66.66                      lbw b Shamsi  2023.0
# 3784      200.00  c Kohler-Cadmore b Salman Irshad  2024.0
# 954        33.33      c Babar Azam b Salman Irshad  2024.0
# 3650      112.90          c Allen b Mohammad Irfan  2021.0
# 812       145.45                  run out (Cooper)  2016.0
# 1674      140.35                           not out  2017.0
# 4063      110.00      c ï¿½Sarfaraz Ahmed b Hosein  2024.0
# 922       180.00      c Umaid Asif b Mohammad Amir  2020.0
# 2631       50.00     c Shadab Khan b Faheem Ashraf  2019.0
#
#                                   stadium               team  \
# 846             National Stadium, Karachi     Peshawar Zalmi
# 1045           Rawalpindi Cricket Stadium  Quetta Gladiators
# 3784              Gaddafi Stadium, Lahore  Quetta Gladiators
# 954               Gaddafi Stadium, Lahore   Islamabad United
# 3650      Sheikh Zayed Stadium, Abu Dhabi  Quetta Gladiators
# 812               Sharjah Cricket Stadium     Peshawar Zalmi
# 1674  Dubai International Cricket Stadium     Peshawar Zalmi
# 4063              Gaddafi Stadium, Lahore   Lahore Qalandars
# 922                Multan Cricket Stadium     Multan Sultans
# 2631            National Stadium, Karachi   Lahore Qalandars
#
#           opposing_team
# 846    Islamabad United
# 1045      Karachi Kings
# 3784     Peshawar Zalmi
# 954      Peshawar Zalmi
# 3650     Peshawar Zalmi
# 812    Lahore Qalandars
# 1674      Karachi Kings
# 4063  Quetta Gladiators
# 922       Karachi Kings
# 2631   Islamabad United

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4496 entries, 0 to 4495
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     4496 non-null   int64
#  1   batsman        4496 non-null   object
#  2   total_runs     4496 non-null   object
#  3   total_balls    4496 non-null   object
#  4   fours          4496 non-null   object
#  5   sixes          4496 non-null   object
#  6   strike_rate    4496 non-null   object
#  7   wicket_taken   4496 non-null   object
#  8   season         4483 non-null   float64
#  9   stadium        4496 non-null   object
#  10  team           4496 non-null   object
#  11  opposing_team  4496 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 421.6+ KB

# %% [markdown]
# ### fill missing values
#
# `season`: missing value `completness`

# %%
# Missing data

df[df.season.isnull()]
# Out:
#       Unnamed: 0           batsman total_runs total_balls fours sixes  \
# 47            34      Shane Watson          7           6     1     0
# 120           15         Umar Amin         38          33     3     2
# 274           35     Ahmed Shehzad         58          51     6     1
# 450           19    Sohaib Maqsood         20          20     3     0
# 781           42  Kamran Akmal ï¿½         21          15     3     1
# 855           26        Wahab Riaz         12           8     1     0
# 1717          28   Daren Sammy (c)         18          16     2     0
# 1760           9      Chris Jordan          0           0     0     0
# 1800          28     Rilee Rossouw         39          32     5     0
# 2073          29    Kieron Pollard          7          12     1     0
# 3055          11       Imam-ul-Haq          3           4     0     0
# 3088           7         Ahsan Ali         25          18     3     1
# 3325           0          Nabi Gul          9          12     0     0
#
#      strike_rate                            wicket_taken  season  \
# 47        116.66                     run out (Umar Amin)     NaN
# 120       115.15      c Sohail Tanvir b Mohammad Hasnain     NaN
# 274       113.72                                 not out     NaN
# 450       100.00                       c Rossouw b Bravo     NaN
# 781       140.00                        b Mohammad Nawaz     NaN
# 855       150.00          run out (Mohammad Nawaz/Bravo)     NaN
# 1717      112.50                c Mohammad Nawaz b Bravo     NaN
# 1760           -                                 not out     NaN
# 1800      121.87                                 not out     NaN
# 2073       58.33  c ï¿½Sarfaraz Ahmed b Mohammad Hasnain     NaN
# 3055       75.00      c Ahmed Shehzad b Mohammad Hasnain     NaN
# 3088      138.88                    c Sammy b Wahab Riaz     NaN
# 3325       75.00           c Ahmed Shehzad b Fawad Ahmed     NaN
#
#                         stadium               team      opposing_team
# 47    National Stadium, Karachi  Quetta Gladiators     Peshawar Zalmi
# 120   National Stadium, Karachi     Peshawar Zalmi  Quetta Gladiators
# 274   National Stadium, Karachi  Quetta Gladiators     Peshawar Zalmi
# 450   National Stadium, Karachi     Peshawar Zalmi  Quetta Gladiators
# 781   National Stadium, Karachi     Peshawar Zalmi  Quetta Gladiators
# 855   National Stadium, Karachi     Peshawar Zalmi  Quetta Gladiators
# 1717  National Stadium, Karachi     Peshawar Zalmi  Quetta Gladiators
# 1760  National Stadium, Karachi     Peshawar Zalmi  Quetta Gladiators
# 1800  National Stadium, Karachi  Quetta Gladiators     Peshawar Zalmi
# 2073  National Stadium, Karachi     Peshawar Zalmi  Quetta Gladiators
# 3055  National Stadium, Karachi     Peshawar Zalmi  Quetta Gladiators
# 3088  National Stadium, Karachi  Quetta Gladiators     Peshawar Zalmi
# 3325  National Stadium, Karachi     Peshawar Zalmi  Quetta Gladiators

# %%
# 2019 season final match (missing season)

df.season.fillna(2019, inplace=True)

# %%
# Test
df[df.season.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, batsman, total_runs, total_balls, fours, sixes, strike_rate, wicket_taken, season, stadium, team, opposing_team]
# Index: []

# %% [markdown]
# ### Fixing data type of columns
# - drop unnamed column
# - `Invalid types`:<br>
#     - season type float
#     - total_runs type object
#     - total_balls type object
#     - total_fours type object
#     - total_sixes type object
#     - strike_rate type object
# - `Strike rate`: some rows contains **-** `invalid`
# - `total_runs`: 4092 index contains **-** `invalid`

# %%
df.season = df.season.astype(int)

# %%
# drop unnamed
df.drop(columns='Unnamed: 0', inplace=True)

# %%
# total_runs
# no record of azam khan(absent hurt) in index 4097 --> drop the row

df[df.total_runs=='-']
# Out:
#             batsman total_runs total_balls fours sixes strike_rate  \
# 4097  Azam Khan ï¿½          -           -     -     -           -
#
#      wicket_taken  season                     stadium              team  \
# 4097  absent hurt    2023  Rawalpindi Cricket Stadium  Islamabad United
#
#          opposing_team
# 4097  Lahore Qalandars

# %%
df.drop(index=4097, axis=0, inplace=True)

# %%
df.total_runs = df.total_runs.astype(int)

# %%
# total_balls

df.total_balls = df.total_balls.astype(int)

# %%
# fours

df.fours = df.fours.astype(int)

# %%
# sixes

df.sixes = df.sixes.astype(int)

# %%
# Strike_rate

df[df['strike_rate'] == '-']
# Out:
#                       batsman  total_runs  total_balls  fours  sixes  \
# 160                Babar Azam           0            0      0      0
# 221             Andre Russell           0            0      0      0
# 295           Kevin Pietersen           0            0      0      0
# 329            Mohammad Nawaz           0            0      0      0
# 515              Kevon Cooper           0            0      0      0
# ...                       ...         ...          ...    ...    ...
# 4068             David Willey           0            0      0      0
# 4144  Shaheen Shah Afridi (c)           0            0      0      0
# 4159               Zaman Khan           0            0      0      0
# 4209            Athar Mahmood           0            0      0      0
# 4230             Akeal Hosein           0            0      0      0
#
#      strike_rate           wicket_taken  season  \
# 160            -  run out (Shadab Khan)    2020
# 221            -                not out    2016
# 295            -   run out (Imad Wasim)    2017
# 329            -                not out    2019
# 515            -                not out    2016
# ...          ...                    ...     ...
# 4068           -                not out    2022
# 4144           -                not out    2022
# 4159           -                not out    2022
# 4209           -                not out    2022
# 4230           -                not out    2023
#
#                                   stadium               team     opposing_team
# 160            Rawalpindi Cricket Stadium      Karachi Kings  Islamabad United
# 221   Dubai International Cricket Stadium   Islamabad United    Peshawar Zalmi
# 295   Dubai International Cricket Stadium  Quetta Gladiators     Karachi Kings
# 329               Sharjah Cricket Stadium  Quetta Gladiators     Karachi Kings
# 515   Dubai International Cricket Stadium   Lahore Qalandars  Islamabad United
# ...                                   ...                ...               ...
# 4068            National Stadium, Karachi     Multan Sultans  Islamabad United
# 4144              Gaddafi Stadium, Lahore   Lahore Qalandars  Islamabad United
# 4159            National Stadium, Karachi   Lahore Qalandars  Islamabad United
# 4209              Gaddafi Stadium, Lahore   Islamabad United  Lahore Qalandars
# 4230               Multan Cricket Stadium     Multan Sultans  Lahore Qalandars
#
# [90 rows x 11 columns]

# %%
df.strike_rate = df.strike_rate.replace('-',0)

# %%
df.strike_rate = df.strike_rate.astype(float)

# %%
# Test
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4495 entries, 0 to 4495
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   batsman        4495 non-null   object
#  1   total_runs     4495 non-null   int32
#  2   total_balls    4495 non-null   int32
#  3   fours          4495 non-null   int32
#  4   sixes          4495 non-null   int32
#  5   strike_rate    4495 non-null   float64
#  6   wicket_taken   4495 non-null   object
#  7   season         4495 non-null   int32
#  8   stadium        4495 non-null   object
#  9   team           4495 non-null   object
#  10  opposing_team  4495 non-null   object
# dtypes: float64(1), int32(5), object(5)
# memory usage: 333.6+ KB

# %%
df.describe()
# Out:
#         total_runs  total_balls        fours        sixes  strike_rate  \
# count  4495.000000  4495.000000  4495.000000  4495.000000  4495.000000
# mean     18.836040    14.269855     1.708788     0.763737   109.302345
# std      21.064992    13.193366     2.295959     1.319220    71.890211
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     4.000000     0.000000     0.000000    60.000000
# 50%      12.000000    10.000000     1.000000     0.000000   109.090000
# 75%      28.000000    21.000000     3.000000     1.000000   150.000000
# max     145.000000    67.000000    20.000000    12.000000   600.000000
#
#             season
# count  4495.000000
# mean   2020.249833
# std       2.493179
# min    2016.000000
# 25%    2018.000000
# 50%    2020.000000
# 75%    2022.000000
# max    2024.000000

# %% [markdown]
# ### Data cleaning batsman name
# - `Batsman name`: **ï¿½** invalid characters `invalid`

# %%
# Code
df[df.batsman.str.contains('ï¿½')]
# Out:
#                batsman  total_runs  total_balls  fours  sixes  strike_rate  \
# 177   Sam Billings ï¿½           2            4      0      0        50.00
# 178   Sam Billings ï¿½          26           20      1      1       130.00
# 179   Sam Billings ï¿½           4            2      1      0       200.00
# 180   Sam Billings ï¿½          47           23      5      3       204.34
# 181   Sam Billings ï¿½          33           23      5      0       143.47
# ...                ...         ...          ...    ...    ...          ...
# 4482   Tim Seifert ï¿½          41           30      8      0       136.66
# 4490  Laurie Evans ï¿½          12           13      2      0        92.30
# 4491  Laurie Evans ï¿½           7            4      1      0       175.00
# 4492  Laurie Evans ï¿½           1            2      0      0        50.00
# 4493  Laurie Evans ï¿½           0            1      0      0         0.00
#
#                               wicket_taken  season  \
# 177                       b Mohammad Nawaz    2016
# 178         c Mohammad Asghar b Wahab Riaz    2016
# 179                        run out (Vince)    2016
# 180                                not out    2023
# 181              c Zeeshan Zameer b Curran    2023
# ...                                    ...     ...
# 4482                     lbw b Aamer Jamal    2024
# 4490                c Powell b Aamer Jamal    2024
# 4491    c Mirza Baig b Shaheen Shah Afridi    2024
# 4492               c Jordan b Abbas Afridi    2024
# 4493  run out (Faheem Ashraf/ï¿½Azam Khan)    2024
#
#                                   stadium               team  \
# 177   Dubai International Cricket Stadium   Islamabad United
# 178   Dubai International Cricket Stadium   Islamabad United
# 179   Dubai International Cricket Stadium   Islamabad United
# 180               Gaddafi Stadium, Lahore   Lahore Qalandars
# 181               Gaddafi Stadium, Lahore   Lahore Qalandars
# ...                                   ...                ...
# 4482            National Stadium, Karachi      Karachi Kings
# 4490           Rawalpindi Cricket Stadium  Quetta Gladiators
# 4491            National Stadium, Karachi  Quetta Gladiators
# 4492            National Stadium, Karachi  Quetta Gladiators
# 4493            National Stadium, Karachi  Quetta Gladiators
#
#           opposing_team
# 177   Quetta Gladiators
# 178      Peshawar Zalmi
# 179       Karachi Kings
# 180      Peshawar Zalmi
# 181    Islamabad United
# ...                 ...
# 4482     Peshawar Zalmi
# 4490     Peshawar Zalmi
# 4491   Lahore Qalandars
# 4492     Multan Sultans
# 4493   Islamabad United
#
# [513 rows x 11 columns]

# %%
df.batsman = df.batsman.str.replace('ï¿½','').str.strip()

# %%
# Test
df[df.batsman.str.contains('ï¿½')]
# Out:
# Empty DataFrame
# Columns: [batsman, total_runs, total_balls, fours, sixes, strike_rate, wicket_taken, season, stadium, team, opposing_team]
# Index: []

# %% [markdown]
# ### Data cleaning wicket_taken column
# -  `wicket_taken`: some rows contains **ï¿½** `invalid`

# %%
df[df.wicket_taken.str.contains('ï¿½')]
# Out:
#             batsman  total_runs  total_balls  fours  sixes  strike_rate  \
# 20     Shane Watson          26           14      2      2       185.71
# 21     Shane Watson          30           22      1      2       136.36
# 26     Shane Watson           1            6      0      0        16.66
# 33     Shane Watson          37           25      6      1       148.00
# 50     Shane Watson          27           20      2      2       135.00
# ...             ...         ...          ...    ...    ...          ...
# 4476    Tim Seifert           8            9      0      1        88.88
# 4479    Tim Seifert          49           31      6      2       158.06
# 4481    Tim Seifert          36           33      2      0       109.09
# 4493   Laurie Evans           0            1      0      0         0.00
# 4494  Arafat Minhas           1            1      0      0       100.00
#
#                                    wicket_taken  season  \
# 20              run out (Pollard/ï¿½Sangakkara)    2017
# 21    run out (sub [CJ Jordan]/ï¿½Kamran Akmal)    2017
# 26                 run out (ï¿½Mohammad Rizwan)    2018
# 33               c ï¿½Kamran Akmal b Umaid Asif    2018
# 50               run out (Umaid Asif/ï¿½Walton)    2020
# ...                                         ...     ...
# 4476               st ï¿½Azam Khan b Imad Wasim    2024
# 4479         st ï¿½Sarfaraz Ahmed b Abrar Ahmed    2024
# 4481            run out (Sikandar Raza/ï¿½Hope)    2024
# 4493       run out (Faheem Ashraf/ï¿½Azam Khan)    2024
# 4494            run out (Sikandar Raza/ï¿½Hope)    2024
#
#                                   stadium               team  \
# 20                Sharjah Cricket Stadium   Islamabad United
# 21                Sharjah Cricket Stadium   Islamabad United
# 26    Dubai International Cricket Stadium  Quetta Gladiators
# 33    Dubai International Cricket Stadium  Quetta Gladiators
# 50              National Stadium, Karachi  Quetta Gladiators
# ...                                   ...                ...
# 4476            National Stadium, Karachi      Karachi Kings
# 4479           Rawalpindi Cricket Stadium      Karachi Kings
# 4481            National Stadium, Karachi      Karachi Kings
# 4493            National Stadium, Karachi  Quetta Gladiators
# 4494            National Stadium, Karachi      Karachi Kings
#
#           opposing_team
# 20        Karachi Kings
# 21       Peshawar Zalmi
# 26        Karachi Kings
# 33       Peshawar Zalmi
# 50        Karachi Kings
# ...                 ...
# 4476   Islamabad United
# 4479  Quetta Gladiators
# 4481   Lahore Qalandars
# 4493   Islamabad United
# 4494   Lahore Qalandars
#
# [546 rows x 11 columns]

# %%
df.wicket_taken = df.wicket_taken.str.replace('ï¿½','').str.strip()

# %%
# Test
df[df.wicket_taken.str.contains('ï¿½')]
# Out:
# Empty DataFrame
# Columns: [batsman, total_runs, total_balls, fours, sixes, strike_rate, wicket_taken, season, stadium, team, opposing_team]
# Index: []

# %% [markdown]
# ### Fixing structure of data
#
# `derived column`: seperate column for whether a player is captain or not.<br>

# %%
# Make new column if a player is captain in that particular match. if yes = 1 and no = 0

df[df.batsman.str.contains("\(c\)")].head()
# Out:
#                batsman  total_runs  total_balls  fours  sixes  strike_rate  \
# 7      Shan Masood (c)           9           17      0      0        52.94
# 190  Misbah-ul-Haq (c)          41           28      4      1       146.42
# 191  Misbah-ul-Haq (c)          12           12      2      0       100.00
# 192  Misbah-ul-Haq (c)           4            6      0      0        66.66
# 193  Misbah-ul-Haq (c)          32           27      3      2       118.51
#
#                      wicket_taken  season  \
# 7                    b Imad Wasim    2020
# 190        c Umar Gul b Anwar Ali    2016
# 191     c Malan b Mohammad Asghar    2016
# 192    c Shakib Al Hasan b Bopara    2016
# 193  c Shahid Afridi b Wahab Riaz    2016
#
#                                  stadium              team      opposing_team
# 7                Gaddafi Stadium, Lahore    Multan Sultans      Karachi Kings
# 190  Dubai International Cricket Stadium  Islamabad United  Quetta Gladiators
# 191  Dubai International Cricket Stadium  Islamabad United     Peshawar Zalmi
# 192  Dubai International Cricket Stadium  Islamabad United      Karachi Kings
# 193              Sharjah Cricket Stadium  Islamabad United     Peshawar Zalmi

# %%
df.insert(6,'captain', 0)

# %%
df['captain'][df.batsman.str.contains("\(c\)")] = 1
# Out:
# C:\Users\aly98\AppData\Local\Temp\ipykernel_75580\2764364724.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['captain'][df.batsman.str.contains("\(c\)")] = 1

# %%
# Fixing the batsman name

df.batsman = df.batsman.str.replace("(c)",'').str.strip()

# %%
# Test

df.head()
# Out:
#            batsman  total_runs  total_balls  fours  sixes  strike_rate  \
# 0      Tamim Iqbal          62           46      4      4       134.78
# 1  Mohammad Hafeez          16           19      2      0        84.21
# 2     Kamran Akmal           0            3      0      0         0.00
# 3      Eoin Morgan           1            4      0      0        25.00
# 4   Sohaib Maqsood          30           24      2      1       125.00
#
#    captain                 wicket_taken  season                  stadium  \
# 0        0                      not out    2017  Sharjah Cricket Stadium
# 1        0  c Hassan Khan b Mahmudullah    2017  Sharjah Cricket Stadium
# 2        0  c Asad Shafiq b Hassan Khan    2017  Sharjah Cricket Stadium
# 3        0      c Asad Shafiq b Rossouw    2017  Sharjah Cricket Stadium
# 4        0                      not out    2017  Sharjah Cricket Stadium
#
#              team      opposing_team
# 0  Peshawar Zalmi  Quetta Gladiators
# 1  Peshawar Zalmi  Quetta Gladiators
# 2  Peshawar Zalmi  Quetta Gladiators
# 3  Peshawar Zalmi  Quetta Gladiators
# 4  Peshawar Zalmi  Quetta Gladiators

# %%
df[df.batsman.str.contains("\(c\)")].head()
# Out:
# Empty DataFrame
# Columns: [batsman, total_runs, total_balls, fours, sixes, strike_rate, captain, wicket_taken, season, stadium, team, opposing_team]
# Index: []

# %% [markdown]
# `wicket_taken`: wicket type and name of wicket taker together<br>

# %%
# add another column 1 for wicket type

df.insert(7,'wicket_type',np.nan)

# %%
df.head()
# Out:
#            batsman  total_runs  total_balls  fours  sixes  strike_rate  \
# 0      Tamim Iqbal          62           46      4      4       134.78
# 1  Mohammad Hafeez          16           19      2      0        84.21
# 2     Kamran Akmal           0            3      0      0         0.00
# 3      Eoin Morgan           1            4      0      0        25.00
# 4   Sohaib Maqsood          30           24      2      1       125.00
#
#    captain  wicket_type                 wicket_taken  season  \
# 0        0          NaN                      not out    2017
# 1        0          NaN  c Hassan Khan b Mahmudullah    2017
# 2        0          NaN  c Asad Shafiq b Hassan Khan    2017
# 3        0          NaN      c Asad Shafiq b Rossouw    2017
# 4        0          NaN                      not out    2017
#
#                    stadium            team      opposing_team
# 0  Sharjah Cricket Stadium  Peshawar Zalmi  Quetta Gladiators
# 1  Sharjah Cricket Stadium  Peshawar Zalmi  Quetta Gladiators
# 2  Sharjah Cricket Stadium  Peshawar Zalmi  Quetta Gladiators
# 3  Sharjah Cricket Stadium  Peshawar Zalmi  Quetta Gladiators
# 4  Sharjah Cricket Stadium  Peshawar Zalmi  Quetta Gladiators

# %%
pd.set_option('display.max_rows', 2000)

# %%
def fix_wicket_type(series):
    data = []
    if series[0] == 'b':
        data.append('bowled')
    elif series[0] == 'r':
        data.append('run out')
    elif series[0] == 'c':
        data.append('catch')
    elif series[0] == 'l':
        data.append('lbw')
    elif series[0] == 's':
        data.append('stumped')
    elif series[0] == 'h':
        data.append('hit wicket')
    elif series[0] == 'o':
        data.append('obstructing the field')
    else:
        data.append('not out')
    return data[0]

# %%
df.wicket_type = df.wicket_taken.apply(fix_wicket_type)

# %%
# Test

df.sample(5)
# Out:
#             batsman  total_runs  total_balls  fours  sixes  strike_rate  \
# 1673    Eoin Morgan           1            3      0      0        33.33
# 379     Chris Gayle          11            9      0      1       122.22
# 986   Sohail Tanvir           3            5      0      0        60.00
# 874     Junaid Khan           0            0      0      0         0.00
# 1678   Haris Sohail          12           14      0      0        85.71
#
#       captain wicket_type               wicket_taken  season  \
# 1673        0      bowled              b Saeed Ajmal    2017
# 379         0       catch  c Morgan b Iftikhar Ahmed    2017
# 986         0      bowled                    b Wiese    2020
# 874         0     not out                    not out    2019
# 1678        0       catch          c Haddin b Watson    2017
#
#                                   stadium            team     opposing_team
# 1673  Dubai International Cricket Stadium  Peshawar Zalmi  Islamabad United
# 379               Sharjah Cricket Stadium   Karachi Kings    Peshawar Zalmi
# 986             National Stadium, Karachi  Multan Sultans  Lahore Qalandars
# 874   Dubai International Cricket Stadium  Multan Sultans     Karachi Kings
# 1678  Dubai International Cricket Stadium  Peshawar Zalmi  Islamabad United

# %% [markdown]
# #### derived column from wicket_taken

# %%
# add column for wicket taker

df.insert(8,'wicket_taken_by',np.nan)

# %%
def fix_wicket_taken(s):
    data = []
    
    if 'not out' in s:
        data.append('not out')
    elif 'run out' in s:
        data.append('run out') 
    elif ' b ' in s or 'b ' in s:
        s = s[s.find(' b ')+2:].strip()
        s = s[1:].strip() if s[0:2] == 'b ' else s
        data.append(s)
    else:
        data.append(s)
    return data[0]

# %%
df['wicket_taken_by'] = df.wicket_taken.apply(fix_wicket_taken)

# %%
# Test

df.sample(5)
# Out:
#                  batsman  total_runs  total_balls  fours  sixes  strike_rate  \
# 1602     Mohammad Asghar           0            2      0      0         0.00
# 1002      Iftikhar Ahmed          14           21      1      0        66.66
# 4363  Azmatullah Omarzai           0            2      0      0         0.00
# 1866         Tymal Mills           0            1      0      0         0.00
# 1610        Shoaib Malik           0            4      0      0         0.00
#
#       captain wicket_type      wicket_taken_by  \
# 1602        0      bowled              Russell
# 1002        0         lbw                Emrit
# 4363        0       catch  Shaheen Shah Afridi
# 1866        0         lbw       Mohammad Irfan
# 1610        0       catch       Mohammad Irfan
#
#                              wicket_taken  season  \
# 1602                            b Russell    2016
# 1002                          lbw b Emrit    2017
# 4363  c Rashid Khan b Shaheen Shah Afridi    2023
# 1866                 lbw b Mohammad Irfan    2017
# 1610            c Haddin b Mohammad Irfan    2016
#
#                                   stadium               team  \
# 1602  Dubai International Cricket Stadium     Peshawar Zalmi
# 1002              Gaddafi Stadium, Lahore     Peshawar Zalmi
# 4363           Rawalpindi Cricket Stadium     Peshawar Zalmi
# 1866  Dubai International Cricket Stadium  Quetta Gladiators
# 1610  Dubai International Cricket Stadium      Karachi Kings
#
#           opposing_team
# 1602   Islamabad United
# 1002  Quetta Gladiators
# 4363   Lahore Qalandars
# 1866   Lahore Qalandars
# 1610   Islamabad United

# %%
df.drop(columns = 'wicket_taken', inplace=True)

# %%
# For better Column Name

df.rename(columns={
    'captain': 'match_captain',
    'wicket_taken_by': 'dismissed_by',
    'stadium': 'venue_name',
    'team': 'team_name',
}, inplace=True)

# %%
# Test

df.sample(10)
# Out:
#                batsman  total_runs  total_balls  fours  sixes  strike_rate  \
# 1902         Jason Roy          37           18      6      1       205.55
# 579        James Vince          37           25      8      0       148.00
# 602       Shoaib Malik          27           25      2      1       108.00
# 1102    Sarfaraz Ahmed          40           33      5      0       121.21
# 2948     Sikandar Raza           0            1      0      0         0.00
# 3422     Sohail Akhtar          34           30      1      3       113.33
# 2712       Liam Dawson          13           18      1      0        72.22
# 3223       Shadab Khan          14           12      1      0       116.66
# 377        Chris Gayle           5            7      1      0        71.42
# 4457  Haseebullah Khan          37           18      4      2       205.55
#
#       match_captain wicket_type dismissed_by  season  \
# 1902              0      bowled  Hunain Shah    2024
# 579               0         lbw  Usman Tariq    2024
# 602               1       catch  Zafar Gohar    2016
# 1102              1       catch   Haris Rauf    2021
# 2948              0       catch    Hasan Ali    2024
# 3422              1     not out      not out    2020
# 2712              0      bowled     Faulkner    2022
# 3223              1       catch  Imran Tahir    2020
# 377               0       catch       Narine    2017
# 4457              0      bowled    Usama Mir    2024
#
#                       venue_name          team_name      opposing_team
# 1902     Gaddafi Stadium, Lahore  Quetta Gladiators   Islamabad United
# 579    National Stadium, Karachi      Karachi Kings  Quetta Gladiators
# 602      Sharjah Cricket Stadium      Karachi Kings   Lahore Qalandars
# 1102   National Stadium, Karachi  Quetta Gladiators   Lahore Qalandars
# 2948     Gaddafi Stadium, Lahore   Lahore Qalandars      Karachi Kings
# 3422     Gaddafi Stadium, Lahore   Lahore Qalandars     Multan Sultans
# 2712     Gaddafi Stadium, Lahore   Islamabad United  Quetta Gladiators
# 3223  Rawalpindi Cricket Stadium   Islamabad United     Multan Sultans
# 377      Sharjah Cricket Stadium      Karachi Kings   Lahore Qalandars
# 4457      Multan Cricket Stadium     Peshawar Zalmi     Multan Sultans

# %%
# export the data to csv file

df.to_csv('PSL_Batsman_Performance_data')
