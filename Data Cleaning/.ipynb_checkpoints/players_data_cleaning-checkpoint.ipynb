# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-cleaning-doc" data-toc-modified-id="Data-cleaning-doc-1">Data cleaning doc</a></span><ul class="toc-item"><li><span><a href="#clean-names-column" data-toc-modified-id="clean-names-column-1.1">clean names column</a></span></li><li><span><a href="#clean-position-column" data-toc-modified-id="clean-position-column-1.2">clean position column</a></span></li><li><span><a href="#clean-batting-and-bowling-style" data-toc-modified-id="clean-batting-and-bowling-style-1.3">clean batting and bowling style</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
path = r"C:\Users\aly98\Desktop\Portfolio project\psl project\Data Extraction BeautifulSoup\uncleaned_players_info.csv"
df = pd.read_csv(path)

# %% [markdown]
# ## Data cleaning doc
#
# - `name` column : AB de Villiers† (unusual character in the end of name) `inaccurate`
# - `name` column : Shoaib Malik(vc) (extra character in name) `inaccurate`
# - `position` column : missing values `completenss`
# - `position` column : Bowling Allrounder (extra word Bowling or Batting) `inaccurate`
# - `batting_style` column : Batting:Right hand Bat (extra word 'Batting') `inaccurate`
# - `bowling_style` column : Bowling:Right arm Offbreak (extra word 'Bowling') `inaccurate`
# - `bowling_style` column : missing value `completeness`

# %%
df.shape
# Out:
# (386, 4)

# %%
df.sample(20)
# Out:
#                names             position           batting_style  \
# 110      Saeed Ajmal               Bowler  Batting:Right hand Bat
# 335    Aftab Ibrahim                  NaN  Batting:Right hand Bat
# 373  Jake Weatherald     Top order Batter   Batting:Left hand Bat
# 219   Dilbar Hussain               Bowler  Batting:Right hand Bat
# 192      Imran Tahir               Bowler  Batting:Right hand Bat
# 194       Andrew Tye               Bowler  Batting:Right hand Bat
# 339      Imam-ul-Haq     Top order Batter   Batting:Left hand Bat
# 16     Waqas Maqsood               Bowler   Batting:Left hand Bat
# 381     Laurie Evans               Batter  Batting:Right hand Bat
# 211       Chris Lynn               Batter  Batting:Right hand Bat
# 188       Haider Ali  Middle order Batter  Batting:Right hand Bat
# 358    Mohammad Arif       Opening Batter  Batting:Right hand Bat
# 78       Hunain Shah               Bowler  Batting:Right hand Bat
# 235   Dominic Drakes   Bowling Allrounder   Batting:Left hand Bat
# 298   Zulfiqar Babar               Bowler  Batting:Right hand Bat
# 265      Daren Sammy           Allrounder  Batting:Right hand Bat
# 120      Daniel Sams           Allrounder  Batting:Right hand Bat
# 260      Jamal Anwar                  NaN  Batting:Right hand Bat
# 42        Babar Azam               Batter  Batting:Right hand Bat
# 47     Sharjeel Khan       Opening Batter   Batting:Left hand Bat
#
#                       bowling_style
# 110      Bowling:Right arm Offbreak
# 335   Bowling:Right arm Medium fast
# 373                Bowling:Legbreak
# 219   Bowling:Right arm Fast medium
# 192         Bowling:Legbreak Googly
# 194   Bowling:Right arm Medium fast
# 339                             NaN
# 16     Bowling:Left arm Fast medium
# 381      Bowling:Right arm Offbreak
# 211  Bowling:Slow Left arm Orthodox
# 188                             NaN
# 358                             NaN
# 78         Bowling:Right arm Medium
# 235    Bowling:Left arm Medium fast
# 298  Bowling:Slow Left arm Orthodox
# 265        Bowling:Right arm Medium
# 120    Bowling:Left arm Fast medium
# 260                             NaN
# 42       Bowling:Right arm Offbreak
# 47                 Bowling:Legbreak

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   names          386 non-null    object
#  1   position       356 non-null    object
#  2   batting_style  386 non-null    object
#  3   bowling_style  342 non-null    object
# dtypes: object(4)
# memory usage: 12.2+ KB

# %% [markdown]
# ### clean names column
# - `name` column : AB de Villiers† (unusual character in the end of name) `inaccurate`

# %%
df[df.names.str.contains('†')]
# Out:
#                     names             position           batting_style  \
# 4            Luke Ronchi†  Wicketkeeper Batter  Batting:Right hand Bat
# 6              Phil Salt†  Wicketkeeper Batter  Batting:Right hand Bat
# 29             Azam Khan†  Wicketkeeper Batter  Batting:Right hand Bat
# 31    Rahmanullah Gurbaz†  Wicketkeeper Batter  Batting:Right hand Bat
# 43          Sam Billings†  Wicketkeeper Batter  Batting:Right hand Bat
# 44           Brad Haddin†  Wicketkeeper Batter  Batting:Right hand Bat
# 59       Muhammad Akhlaq†  Wicketkeeper Batter  Batting:Right hand Bat
# 60          Rohail Nazir†  Wicketkeeper Batter  Batting:Right hand Bat
# 71            Jordan Cox†  Wicketkeeper Batter  Batting:Right hand Bat
# 91              Ben Dunk†  Wicketkeeper Batter   Batting:Left hand Bat
# 92       Mohammad Rizwan†  Wicketkeeper Batter  Batting:Right hand Bat
# 107      Nicholas Pooran†  Wicketkeeper Batter   Batting:Left hand Bat
# 113          Tim Seifert†  Wicketkeeper Batter  Batting:Right hand Bat
# 130      Mushfiqur Rahim†  Wicketkeeper Batter  Batting:Right hand Bat
# 132    Saifullah Bangash†  Wicketkeeper Batter  Batting:Right hand Bat
# 159       Mohammad Haris†  Wicketkeeper Batter  Batting:Right hand Bat
# 162           Litton Das†  Wicketkeeper Batter  Batting:Right hand Bat
# 167       AB de Villiers†  Wicketkeeper Batter  Batting:Right hand Bat
# 172       Brendan Taylor†  Wicketkeeper Batter  Batting:Right hand Bat
# 190         Matthew Wade†  Wicketkeeper Batter   Batting:Left hand Bat
# 215           Dane Vilas†  Wicketkeeper Batter  Batting:Right hand Bat
# 229  Mohammad Rizwan† (c)  Wicketkeeper Batter  Batting:Right hand Bat
# 230      Johnson Charles†  Wicketkeeper Batter  Batting:Right hand Bat
# 247       Zeeshan Ashraf†  Wicketkeeper Batter   Batting:Left hand Bat
# 252         Kamran Akmal†  Wicketkeeper Batter  Batting:Right hand Bat
# 262       Jonny Bairstow†  Wicketkeeper Batter  Batting:Right hand Bat
# 292       Bismillah Khan†  Wicketkeeper Batter  Batting:Right hand Bat
# 300   Sarfaraz Ahmed† (c)  Wicketkeeper Batter  Batting:Right hand Bat
# 306   Tom Kohler-Cadmore†  Wicketkeeper Batter  Batting:Right hand Bat
# 316     Kumar Sangakkara†  Wicketkeeper Batter   Batting:Left hand Bat
# 321     Haseebullah Khan†  Wicketkeeper Batter   Batting:Left hand Bat
# 337           Tom Banton†  Wicketkeeper Batter  Batting:Right hand Bat
# 354       Sarfaraz Ahmed†  Wicketkeeper Batter  Batting:Right hand Bat
#
#                      bowling_style
# 4                              NaN
# 6       Bowling:Right arm Offbreak
# 29                             NaN
# 31        Bowling:Right arm Medium
# 43                             NaN
# 44                             NaN
# 59   Bowling:Right arm Medium fast
# 60                             NaN
# 71                             NaN
# 91      Bowling:Right arm Offbreak
# 92        Bowling:Right arm Medium
# 107     Bowling:Right arm Offbreak
# 113                            NaN
# 130                            NaN
# 132                            NaN
# 159     Bowling:Right arm Offbreak
# 162     Bowling:Right arm Offbreak
# 167       Bowling:Right arm Medium
# 172     Bowling:Right arm Offbreak
# 190       Bowling:Right arm Medium
# 215                            NaN
# 229       Bowling:Right arm Medium
# 230                            NaN
# 247     Bowling:Right arm Offbreak
# 252                            NaN
# 262       Bowling:Right arm Medium
# 292                            NaN
# 300     Bowling:Right arm Offbreak
# 306     Bowling:Right arm Offbreak
# 316     Bowling:Right arm Offbreak
# 321                            NaN
# 337                            NaN
# 354     Bowling:Right arm Offbreak

# %%
df.names = df.names.str.replace('†','')

# %%
# Test
df[df.names.str.contains('†')]
# Out:
# Empty DataFrame
# Columns: [names, position, batting_style, bowling_style]
# Index: []

# %% [markdown]
# - `name` column : Shoaib Malik(vc) (extra character in name) `inaccurate`

# %%
df[df.names.str.contains('\(')]
# Out:
#                    names             position           batting_style  \
# 12      Mohammad Sami(c)               Bowler  Batting:Right hand Bat
# 25        Shadab Khan(c)           Allrounder  Batting:Right hand Bat
# 85      Misbah-ul-Haq(c)  Middle order Batter  Batting:Right hand Bat
# 93         Imad Wasim(c)           Allrounder   Batting:Left hand Bat
# 134      Shoaib Malik(c)           Allrounder  Batting:Right hand Bat
# 138        Babar Azam(c)               Batter  Batting:Right hand Bat
# 157       Babar Azam(vc)               Batter  Batting:Right hand Bat
# 173   Mohammad Hafeez(c)           Allrounder  Batting:Right hand Bat
# 216     Sohail Akhtar(c)           Allrounder  Batting:Right hand Bat
# 221  Brendon McCullum(c)  Wicketkeeper Batter  Batting:Right hand Bat
# 229  Mohammad Rizwan (c)  Wicketkeeper Batter  Batting:Right hand Bat
# 244       Shan Masood(c)       Opening Batter   Batting:Left hand Bat
# 253       Daren Sammy(c)           Allrounder  Batting:Right hand Bat
# 277   Mohammad Rizwan(c)  Wicketkeeper Batter  Batting:Right hand Bat
# 284    Sarfaraz Ahmed(c)  Wicketkeeper Batter  Batting:Right hand Bat
# 300   Sarfaraz Ahmed (c)  Wicketkeeper Batter  Batting:Right hand Bat
# 308        Wahab Riaz(c)               Bowler  Batting:Right hand Bat
# 351     Shoaib Malik(vc)           Allrounder  Batting:Right hand Bat
# 370     Shane Watson(vc)           Allrounder  Batting:Right hand Bat
# 374   Mohammad Nawaz(vc)           Allrounder   Batting:Left hand Bat
#
#                                     bowling_style
# 12                         Bowling:Right arm Fast
# 25                               Bowling:Legbreak
# 85                               Bowling:Legbreak
# 93                 Bowling:Slow Left arm Orthodox
# 134                    Bowling:Right arm Offbreak
# 138                    Bowling:Right arm Offbreak
# 157                    Bowling:Right arm Offbreak
# 173                    Bowling:Right arm Offbreak
# 216                      Bowling:Right arm Medium
# 221  Bowling:Right arm Medium, Right arm Offbreak
# 229                      Bowling:Right arm Medium
# 244                 Bowling:Right arm Medium fast
# 253                      Bowling:Right arm Medium
# 277                      Bowling:Right arm Medium
# 284                    Bowling:Right arm Offbreak
# 300                    Bowling:Right arm Offbreak
# 308                         Bowling:Left arm Fast
# 351                    Bowling:Right arm Offbreak
# 370                 Bowling:Right arm Fast medium
# 374                Bowling:Slow Left arm Orthodox

# %%
df.names = df.names.str.replace('(c)','')
df.names = df.names.str.replace('(vc)','')

# %%
# Test
df[df.names.str.contains('\(')]
# Out:
# Empty DataFrame
# Columns: [names, position, batting_style, bowling_style]
# Index: []

# %% [markdown]
# ### clean position column
#
# - `position` column : missing values `completenss`

# %%
df.position.isnull().sum()
# Out:
# 30

# %%
df[df.position.isnull()]
# Out:
#                    names position            batting_style  \
# 19           Nasir Nawaz      NaN   Batting:Right hand Bat
# 41       Rachel Gnanaraj      NaN   Batting:Right hand Bat
# 55          Imran Khalid      NaN    Batting:Left hand Bat
# 83           Shahab Khan      NaN  Bowling:Left arm Medium
# 84        Shamyl Hussain      NaN    Batting:Left hand Bat
# 104           Jaahid Ali      NaN   Batting:Right hand Bat
# 105        Aaron Summers      NaN   Batting:Right hand Bat
# 129            Saad Baig      NaN    Batting:Left hand Bat
# 151          Talha Ahsan      NaN   Batting:Right hand Bat
# 186           Gauhar Ali      NaN   Batting:Right hand Bat
# 187         Umair Masood      NaN   Batting:Right hand Bat
# 210         Adnan Rasool      NaN   Batting:Right hand Bat
# 243  Muhammad Amir Barki      NaN   Batting:Right hand Bat
# 260          Jamal Anwar      NaN   Batting:Right hand Bat
# 261             Nabi Gul      NaN   Batting:Right hand Bat
# 269       Musaddiq Ahmed      NaN   Batting:Right hand Bat
# 276      Mohammad Sarwar      NaN   Batting:Right hand Bat
# 290           Jalat Khan      NaN    Batting:Left hand Bat
# 299            Noor Wali      NaN   Batting:Right hand Bat
# 335        Aftab Ibrahim      NaN   Batting:Right hand Bat
# 336     Muhammad Shahzad      NaN   Batting:Right hand Bat
# 342            Aamir Ali      NaN    Batting:Left hand Bat
# 343            Adil Amin      NaN   Batting:Right hand Bat
# 356           Aimal Khan      NaN   Batting:Right hand Bat
# 357       Mohammad Zahid      NaN   Batting:Right hand Bat
# 362              Li Jian      NaN   Batting:Right hand Bat
# 369         Umair Afridi      NaN    Batting:Left hand Bat
# 383             Adil Naz      NaN   Batting:Right hand Bat
# 384           Sajjad Ali      NaN   Batting:Right hand Bat
# 385          Usman Tariq      NaN   Batting:Right hand Bat
#
#                       bowling_style
# 19    Bowling:Right arm Medium fast
# 41         Bowling:Right arm Medium
# 55   Bowling:Slow Left arm Orthodox
# 83                              NaN
# 84                              NaN
# 104      Bowling:Right arm Offbreak
# 105          Bowling:Right arm Fast
# 129                             NaN
# 151                Bowling:Legbreak
# 186                             NaN
# 187                             NaN
# 210      Bowling:Right arm Offbreak
# 243      Bowling:Right arm Offbreak
# 260                             NaN
# 261                             NaN
# 269                             NaN
# 276   Bowling:Right arm Fast medium
# 290  Bowling:Slow Left arm Orthodox
# 299        Bowling:Right arm Medium
# 335   Bowling:Right arm Medium fast
# 336   Bowling:Right arm Medium fast
# 342  Bowling:Slow Left arm Orthodox
# 343      Bowling:Right arm Offbreak
# 356        Bowling:Right arm Medium
# 357          Bowling:Right arm Fast
# 362   Bowling:Right arm Medium fast
# 369         Bowling:Left arm Medium
# 383                             NaN
# 384                             NaN
# 385      Bowling:Right arm Offbreak

# %%
# Manually to find each batter missing field

p1 = ['Batter','Batter','Bowler','Batter','Batter','Batter','Bowler','Batter', 'Batter', 'Bowler',
      'Wicketkeeper Batter','Bowler', 'Batter','Wicketkeeper Batter', 'Batter','Batter',
      'All rounder','Bowler','Bowler','Bowler','Wicketkeeper Batter', 'Bowler', 'All rounder', 'Bowler','Bowler', 'All rounder',
      'Bowler', 'Batter', 'Wicketkeeper Batter', 'Bowler']
len(p1)
# Out:
# 30

# %%
df.position[df.position.isnull()] = p1
# Out:
# C:\Users\aly98\AppData\Local\Temp\ipykernel_33772\407711789.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.position[df.position.isnull()] = p1

# %%
# Test

df[df.position.isnull()]
# Out:
# Empty DataFrame
# Columns: [names, position, batting_style, bowling_style]
# Index: []

# %% [markdown]
# - `position` column : Bowling Allrounder (extra word Bowling or Batting) `inaccurate`

# %%
df[df.position.str.contains('All')]
# Out:
#                names            position           batting_style  \
# 7          Amad Butt  Bowling Allrounder  Batting:Right hand Bat
# 8      Faheem Ashraf  Bowling Allrounder   Batting:Left hand Bat
# 9      Hussain Talat          Allrounder   Batting:Left hand Bat
# 10       Samit Patel          Allrounder  Batting:Right hand Bat
# 11       Shadab Khan          Allrounder  Batting:Right hand Bat
# ..               ...                 ...                     ...
# 371      Abdul Nasir          Allrounder  Batting:Right hand Bat
# 372       Keemo Paul          Allrounder  Batting:Right hand Bat
# 374   Mohammad Nawaz          Allrounder   Batting:Left hand Bat
# 375  Jack Wildermuth          Allrounder  Batting:Right hand Bat
# 378      Rashid Khan  Bowling Allrounder  Batting:Right hand Bat
#
#                       bowling_style
# 7            Bowling:Right arm Fast
# 8          Bowling:Right arm Medium
# 9     Bowling:Right arm Medium fast
# 10   Bowling:Slow Left arm Orthodox
# 11                 Bowling:Legbreak
# ..                              ...
# 371      Bowling:Right arm Offbreak
# 372   Bowling:Right arm Fast medium
# 374  Bowling:Slow Left arm Orthodox
# 375   Bowling:Right arm Medium fast
# 378         Bowling:Legbreak Googly
#
# [104 rows x 4 columns]

# %%
df.position = df.position.str.replace('Bowling','').str.strip()
df.position = df.position.str.replace('Batting','').str.strip()

# %%
# Test

df[df.position.str.contains('All')]
# Out:
#                names    position           batting_style  \
# 7          Amad Butt  Allrounder  Batting:Right hand Bat
# 8      Faheem Ashraf  Allrounder   Batting:Left hand Bat
# 9      Hussain Talat  Allrounder   Batting:Left hand Bat
# 10       Samit Patel  Allrounder  Batting:Right hand Bat
# 11       Shadab Khan  Allrounder  Batting:Right hand Bat
# ..               ...         ...                     ...
# 371      Abdul Nasir  Allrounder  Batting:Right hand Bat
# 372       Keemo Paul  Allrounder  Batting:Right hand Bat
# 374   Mohammad Nawaz  Allrounder   Batting:Left hand Bat
# 375  Jack Wildermuth  Allrounder  Batting:Right hand Bat
# 378      Rashid Khan  Allrounder  Batting:Right hand Bat
#
#                       bowling_style
# 7            Bowling:Right arm Fast
# 8          Bowling:Right arm Medium
# 9     Bowling:Right arm Medium fast
# 10   Bowling:Slow Left arm Orthodox
# 11                 Bowling:Legbreak
# ..                              ...
# 371      Bowling:Right arm Offbreak
# 372   Bowling:Right arm Fast medium
# 374  Bowling:Slow Left arm Orthodox
# 375   Bowling:Right arm Medium fast
# 378         Bowling:Legbreak Googly
#
# [104 rows x 4 columns]

# %% [markdown]
# ### clean batting and bowling style
#
# - `batting_style` column : Batting:Right hand Bat (extra word 'Batting') `inaccurate`

# %%
df.sample(5)
# Out:
#                   names             position           batting_style  \
# 189        Tayyab Tahir  Middle order Batter  Batting:Right hand Bat
# 356          Aimal Khan               Bowler  Batting:Right hand Bat
# 306  Tom Kohler-Cadmore  Wicketkeeper Batter  Batting:Right hand Bat
# 72      Muhammad Waseem       Opening Batter  Batting:Right hand Bat
# 214         Tamim Iqbal       Opening Batter   Batting:Left hand Bat
#
#                   bowling_style
# 189     Bowling:Legbreak Googly
# 356    Bowling:Right arm Medium
# 306  Bowling:Right arm Offbreak
# 72     Bowling:Right arm Medium
# 214                         NaN

# %%
df.batting_style = df.batting_style.str.replace('Batting:','').str.strip()

# %%
# test

df.sample(5)
# Out:
#                names             position   batting_style  \
# 71        Jordan Cox  Wicketkeeper Batter  Right hand Bat
# 27        Akif Javed               Bowler  Right hand Bat
# 127   Tabraiz Shamsi               Bowler  Right hand Bat
# 360     Riki Wessels  Middle order Batter  Right hand Bat
# 107  Nicholas Pooran  Wicketkeeper Batter   Left hand Bat
#
#                     bowling_style
# 71                            NaN
# 27   Bowling:Left arm Medium fast
# 127   Bowling:Left arm Wrist spin
# 360                           NaN
# 107    Bowling:Right arm Offbreak

# %% [markdown]
# - `bowling_style` column : Bowling:Right arm Offbreak (extra word 'Bowling') `inaccurate`

# %%
df.bowling_style = df.bowling_style.str.replace('Bowling:','').str.strip()

# %%
# test

df.sample(5)
# Out:
#                   names             position   batting_style  \
# 381        Laurie Evans               Batter  Right hand Bat
# 98        Sikandar Raza           Allrounder  Right hand Bat
# 181  Sandeep Lamichhane               Bowler  Right hand Bat
# 350      Jonathan Wells  Middle order Batter  Right hand Bat
# 185          Yasir Shah               Bowler  Right hand Bat
#
#                     bowling_style
# 381            Right arm Offbreak
# 98   Right arm Offbreak, Legbreak
# 181               Legbreak Googly
# 350              Right arm Medium
# 185               Legbreak Googly

# %% [markdown]
# - `bowling_style` column : missing value `completeness`

# %%
df[df.bowling_style.isnull()]
# Out:
#                  names             position                 batting_style  \
# 3       Rizwan Hussain               Batter                 Left hand Bat
# 4          Luke Ronchi  Wicketkeeper Batter                Right hand Bat
# 5     Sahibzada Farhan  Middle order Batter                Right hand Bat
# 29           Azam Khan  Wicketkeeper Batter                Right hand Bat
# 43        Sam Billings  Wicketkeeper Batter                Right hand Bat
# 44         Brad Haddin  Wicketkeeper Batter                Right hand Bat
# 58        Brandon King     Top order Batter                Right hand Bat
# 60        Rohail Nazir  Wicketkeeper Batter                Right hand Bat
# 67   Muhammad Hurraira               Batter                Right hand Bat
# 71          Jordan Cox  Wicketkeeper Batter                Right hand Bat
# 83         Shahab Khan               Batter       Bowling:Left arm Medium
# 84      Shamyl Hussain               Batter                 Left hand Bat
# 86      Mohammad Hasan  Middle order Batter                Right hand Bat
# 87     Chadwick Walton     Top order Batter                Right hand Bat
# 113        Tim Seifert  Wicketkeeper Batter                Right hand Bat
# 126     Muhammad Rohid               Bowler  Bowling:Left arm Medium fast
# 129          Saad Baig               Batter                 Left hand Bat
# 130    Mushfiqur Rahim  Wicketkeeper Batter                Right hand Bat
# 132  Saifullah Bangash  Wicketkeeper Batter                Right hand Bat
# 139         Joe Clarke     Top order Batter                Right hand Bat
# 186         Gauhar Ali               Bowler                Right hand Bat
# 187       Umair Masood  Wicketkeeper Batter                Right hand Bat
# 188         Haider Ali  Middle order Batter                Right hand Bat
# 214        Tamim Iqbal       Opening Batter                 Left hand Bat
# 215         Dane Vilas  Wicketkeeper Batter                Right hand Bat
# 222          Jason Roy       Opening Batter                Right hand Bat
# 230    Johnson Charles  Wicketkeeper Batter                Right hand Bat
# 252       Kamran Akmal  Wicketkeeper Batter                Right hand Bat
# 260        Jamal Anwar  Wicketkeeper Batter                Right hand Bat
# 261           Nabi Gul               Batter                Right hand Bat
# 269     Musaddiq Ahmed               Batter                Right hand Bat
# 278    Shimron Hetmyer  Middle order Batter                 Left hand Bat
# 292     Bismillah Khan  Wicketkeeper Batter                Right hand Bat
# 321   Haseebullah Khan  Wicketkeeper Batter                 Left hand Bat
# 332         Yasir Khan     Top order Batter                Right hand Bat
# 337         Tom Banton  Wicketkeeper Batter                Right hand Bat
# 339        Imam-ul-Haq     Top order Batter                 Left hand Bat
# 344    Abdul Bangalzai               Batter                Right hand Bat
# 353       Omair Yousuf               Batter                Right hand Bat
# 358      Mohammad Arif       Opening Batter                Right hand Bat
# 359     Taimoor Sultan       Opening Batter                Right hand Bat
# 360       Riki Wessels  Middle order Batter                Right hand Bat
# 383           Adil Naz               Batter                Right hand Bat
# 384         Sajjad Ali  Wicketkeeper Batter                Right hand Bat
#
#     bowling_style
# 3             NaN
# 4             NaN
# 5             NaN
# 29            NaN
# 43            NaN
# 44            NaN
# 58            NaN
# 60            NaN
# 67            NaN
# 71            NaN
# 83            NaN
# 84            NaN
# 86            NaN
# 87            NaN
# 113           NaN
# 126           NaN
# 129           NaN
# 130           NaN
# 132           NaN
# 139           NaN
# 186           NaN
# 187           NaN
# 188           NaN
# 214           NaN
# 215           NaN
# 222           NaN
# 230           NaN
# 252           NaN
# 260           NaN
# 261           NaN
# 269           NaN
# 278           NaN
# 292           NaN
# 321           NaN
# 332           NaN
# 337           NaN
# 339           NaN
# 344           NaN
# 353           NaN
# 358           NaN
# 359           NaN
# 360           NaN
# 383           NaN
# 384           NaN

# %% [markdown]
# All players who are batters don't ball

# %%
df.rename(columns = )
# Out:
# Index(['names', 'position', 'batting_style', 'bowling_style'], dtype='object')

# %%
df.to_csv('Players_info.csv', index=False)
